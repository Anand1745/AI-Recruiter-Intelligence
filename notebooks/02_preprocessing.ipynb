# %% [markdown]
# Test Pipeline

# %%
import sys
from src.data_loader import CandidateDataLoader
from src.candidate_processor import CandidateProcessor
from src.feature_engineering import FeatureEngineer
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
DATA_PATH = PROJECT_ROOT / "data" / "candidates.jsonl"

loader = CandidateDataLoader(DATA_PATH)
processor = CandidateProcessor()
engineer = FeatureEngineer()

candidates = loader.load_candidates()

candidate = candidates[0]

profile = processor.process_profile(candidate)
skills = processor.process_skills(candidate)
education = processor.process_education(candidate)
certs = processor.process_certifications(candidate)
redrob = processor.process_redrob(candidate)

features = engineer.create_features(
    profile,
    skills,
    education,
    certs,
    redrob
)

features
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 12
#       8
#       9 processor = CandidateProcessor()
#      10 engineer = FeatureEngineer()
#      11
# ---> 12 candidates = loader.load_candidates()
#      13
#      14 candidate = candidates[0]
#      15
#
# File d:\indiaruns\AI-Recruiter-Intelligence\src\data_loader.py:12, in CandidateDataLoader.load_candidates(self)
#       9 def load_candidates(self):
#      10     candidates = []
# ---> 12     with open(self.file_path, "r", encoding="utf-8") as f:
#      13         for line in f:
#      14             candidates.append(json.loads(line))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\candidates.jsonl'
